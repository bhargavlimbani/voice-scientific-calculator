# %%
import math

def calculate_expression(expression):
    
    try:
        result = eval(expression, {"math": math})
        return result
    
    except Exception as e:
        print("Error:", e)
        return "Invalid Expression"


# Test example
print(calculate_expression("100 + 100"))
print(calculate_expression("math.sin(math.radians(30))"))
# Out:
# 200
# 0.49999999999999994
